# %%
import time
import psutil
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
# %matplotlib notebook

# %%
with open('./lunatic_data_2023_03_12_23_00_27_119.json') as f:
    data = json.load(f)
    
# with open('/tmp/data_exchange/data_capture/lunatic_data_2023_03_09_14_54_17_101.json', 'r') as f:
#     data = json.load(f)

df = pd.DataFrame({'count': data})

# %%
df.loc['right'][0] = float(df.loc['right'][0])
df.loc['left'][0] = float(df.loc['left'][0])

# %%
display(df)
# Out:
#               count
# date     2023/03/12
# left          28.75
# right        155.75
# time   23:00:27:119

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1,1,1)

fig.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
i = 0
x,y = [], []

while True:
    x.append(i)
    y.append(df.loc['right'][0])
    ax.plot(x, y, color='b')
    fig.canvas.draw()
    time.sleep(1)
    i+=1
